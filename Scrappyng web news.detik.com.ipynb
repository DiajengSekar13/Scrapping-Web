# %%
from bs4 import BeautifulSoup
import requests
import argparse
import random
import pandas
import time

# %%
url = "https://news.detik.com"
req = requests.get(url)
# print(req)
# print('---------')
# print(req.text)

# %%
soup = BeautifulSoup(req.text, "html.parser")
print(soup.link)
# Out:
# <link href="https://cdn.detik.net.id" rel="dns-prefetch"/>

# %%
for tag in soup.find_all('a'):
  if (tag.get('dtr-evt') == 'headline') : print(tag.get('dtr-evt'), ': ',tag.get('dtr-ttl'))
# Out:
# headline :  Gerindra soal Baliho Prabowo dan Jokowi: Endorse Persatuan Bangsa
# headline :  Gerindra soal Baliho Prabowo dan Jokowi: Endorse Persatuan Bangsa
# headline :  Sandiaga Akui Kini Beda dengan Anies: Gagasan Saya Bukan Perubahan
# headline :  Muncul Baliho Prabowo dan Jokowi 'Menang Bersama untuk Indonesia Raya'

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #
# https://www.detik.com/?tagfrom=framebar
# https://www.detik.com/terpopuler
# https://news.detik.com/kolom/kirim
# https://20.detik.com/live/
# https://news.detik.com/pemilu/
# https://news.detik.com
# https://finance.detik.com
# https://inet.detik.com
# https://hot.detik.com
# https://sport.detik.com
# https://sport.detik.com/sepakbola
# https://oto.detik.com
# https://travel.detik.com
# https://food.detik.com
# https://health.detik.com
# https://wolipop.detik.com
# https://news.detik.com/x/
# https://20.detik.com
# https://foto.detik.com
# https://www.detik.com/edu/
# https://www.detik.com/hikmah/
# https://www.detik.com/jateng
# https://www.detik.com/jatim
# https://www.detik.com/jabar
# https://www.detik.com/sulsel
# https://www.detik.com/sumut
# https://www.detik.com/bali
# https://www.detik.com/sumbagsel
# https://pasangmata.detik.com
# https://adsmart.detik.com
# https://forum.detik.com
# https://event.detik.com
# https://www.transentertainment.com/transsnow
# ...

# %%
url = "https://e-katalog.lkpp.go.id/id/search-produk?authenticityToken=b68341f7a3b1f9050edc290456ae00063aeb8ca8&q=paracetamol&prid=&pid=&gt=&lt=&mid=&kbid=&order=&cat="
req = requests.get(url)

# %%
soup = BeautifulSoup(req.text, "html.parser")
print(req.text)
# Out:
# <!DOCTYPE html>
#
# <html lang="id">
#     <head>
#     	<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
# 		<meta content="width=device-width, initial-scale=1" name="viewport" />
#         <title>E-Katalog 5.0</title>
#         <link rel="icon" type="image/x-icon" href="/public/images/favicon.png">
#         <link rel="stylesheet" media="screen" href="/public/stylesheets/app.min.css">
# 		<link rel="stylesheet" media="screen" href="/public/fa/css/font-awesome.min.css">
# 		<link rel="stylesheet" media="screen" href="/public/stylesheets/bootstrap-datatables-v1_10_8.min.css">
# 		<link rel="stylesheet" media="screen" href="/public/stylesheets/landing.css">
#         <link rel="stylesheet" media="screen" href="/public/stylesheets/bootstrap-social.css">
# 		<link rel="stylesheet" media="screen" href="/public/stylesheets/input-icon.css">
# ...

# %%
import pandas as pd

df = pd.DataFrame()

for div in soup.find_all('div', class_='card-item-detail'):
    title = div.find_all('div', class_='card-item-title')[1].find_all('a')[0].get('title')
    harga = div.find_all('p')[-1].getText()
        
    df = df.append({'nama barang' : title,
                    'harga' : harga} , 
                    ignore_index=True)
    print(div, '\n\n')
# Out:
# <div class="card-item-detail" style="height: 100%;">
# <div class="card-item-title" style="margin-bottom: 2px;height: 22px;background: #cd7c89;border-radius: 50px;padding-top: 2px;">
# <span style="background-image: url('/public/images/pdn.gif');background-repeat: no-repeat;background-size: 19px;padding: 12px;background-position: 4px;" title="Produk Dalam Negeri"></span>
# </div>
# <div class="card-item-title">
# <a data-placement="bottom" data-toggle="tooltip" href="/katalog/produk/detail/47966619?lang=id&amp;type=province" title="Generik Paracetamol/ Parasetamol sirup 120 mg / 5 ml">Generik Paracetamol/ Parasetamol sirup 120 mg...</a>
# </div>
# <div class="card-item-description">
# <p style="white-space: nowrap;overflow:hidden;text-overflow:ellipsis;">PT.Bernofarm</p>
# <p style="white-space: nowrap;overflow:hidden;text-overflow:ellipsis;font-weight: bold">TKDN(%) : 38.14</p>
# <p style="white-space: nowrap;overflow:hidden;text-overflow:ellipsis;font-weight: bold">BMP : 15.0</p>
# ...

# %%
# Out:
#                                           nama barang  \
# 0   Generik Paracetamol/ Parasetamol sirup 120 mg ...
# 1                                     PARACETAMOL 500
# 2   Paracetamol/ Parasetamol tablet/kapsul/kaplet ...
# 3   Paracetamol/ Parasetamol tablet/kapsul/kaplet ...
# 4   Generik Paracetamol/ Parasetamol infus 10 mg/M...
# 5   Generik Paracetamol/ Parasetamol sirup 120 mg ...
# 6   FLUCADEX - OBAT BATUK & FLU KOMBINASI : PARACE...
# 7                                  PARACETAMOL  Syrup
# 8   Generik Paracetamol/ Parasetamol drops 100 mg/...
# 9   Paracetamol Drops 100 mg/ml PARACETAMOL DROPS ...
# 10    GENERIK PARASETAMOL/PARACETAMOL SYRUP 120MG/5ML
# 11                              PARACETAMOL SYR 60 ML
#
#                             harga
# 0     IDR 3,885.00 - IDR 4,662.00
# 1         IDR 307.78 - IDR 495.68
# 2         IDR 160.00 - IDR 200.00
# 3                      IDR 160.00
# 4   IDR 12,765.00 - IDR 17,500.00
# 5     IDR 4,300.00 - IDR 5,300.00
# ...
